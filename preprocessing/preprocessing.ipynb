# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wdbc.csv")
df.head(10)
# Out:
#          ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
# print(df.iloc[0:6,0:7].to_latex(index=False))

# %%
import copy

column_list = [column for column in df] #获得所有列名列表
num_col = copy.deepcopy(column_list)
del num_col[0:2]    #获得连续性数值数据（不含ID与Diagnosis列）的列名列表

nums = [i for i in range(0, 32) if i > 1 ]
df_num = df.iloc[:,nums]
df_num
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
for i in num_col:
    print(i,'列的均值为%.5f'%df[i].mean(),'方差为%.5f'%df[i].std(),'\n')
# Out:
# radius_mean 列的均值为14.12729 方差为3.52405
#
# texture_mean 列的均值为19.28965 方差为4.30104
#
# perimeter_mean 列的均值为91.96903 方差为24.29898
#
# area_mean 列的均值为654.88910 方差为351.91413
#
# smoothness_mean 列的均值为0.09636 方差为0.01406
#
# compactness_mean 列的均值为0.10434 方差为0.05281
#
# concavity_mean 列的均值为0.08880 方差为0.07972
#
# concave_points_mean 列的均值为0.04892 方差为0.03880
#
# symmetry_mean 列的均值为0.18116 方差为0.02741
#
# fractal_dimension_mean 列的均值为0.06280 方差为0.00706
#
# radius_se 列的均值为0.40517 方差为0.27731
#
# texture_se 列的均值为1.21685 方差为0.55165
#
# perimeter_se 列的均值为2.86606 方差为2.02185
#
# area_se 列的均值为40.33708 方差为45.49101
#
# smoothness_se 列的均值为0.00704 方差为0.00300
#
# compactness_se 列的均值为0.02548 方差为0.01791
#
# concavity_se 列的均值为0.03189 方差为0.03019
#
# symmetry_se 列的均值为0.01180 方差为0.00617
#
# concave_points_mean.1 列的均值为0.02054 方差为0.00827
#
# fractal_dimension_se 列的均值为0.00379 方差为0.00265
#
# radius_worst 列的均值为16.26919 方差为4.83324
#
# texture_wost 列的均值为25.67722 方差为6.14626
#
# perimeter_worst 列的均值为107.26121 方差为33.60254
#
# ...

# %%
import math
import matplotlib.pyplot as plt

# define the number of rows and columns in the subplot grid
nrows = 6
ncols = 5

# create a new figure object with a specific size
fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, 16))

# flatten the axs array to make it easier to iterate over
axs = axs.ravel()

# iterate over the continuous columns and create a boxplot for each one
for i, col in enumerate(num_col):
    # select the current subplot
    ax = axs[i]
    
    # create the boxplot on the current subplot
    ax.boxplot(df[col])
    
    # set the subplot title and axis labels
    ax.set_title('Box plot of column '+col)
    ax.set_xlabel('Data')
    ax.set_ylabel('Value')
    
    # hide the x-axis tick labels on all but the bottom row of subplots
    if i < (nrows - 1) * ncols:
        ax.set_xticklabels([])
    
    # hide the y-axis tick labels on all but the leftmost column of subplots
    if i % ncols != 0:
        ax.set_yticklabels([])
    
# adjust the layout of the subplots and display the figure
plt.tight_layout()

# save the figure to the current directory
fig.savefig('boxplots.png', dpi=300)

# show the figure
plt.show()

# %% [markdown]
# ## 数据标准化

# %% [markdown]
# ## z-score方法

# %%
print(df_zscore.iloc[0:6,0:7].to_latex(index=False)) #获得df_zscore部分表格的latex代码
# Out:
# \begin{tabular}{rlrrrrr}
# \toprule
#       ID & Diagnosis &  radius\_mean &  texture\_mean &  perimeter\_mean &  area\_mean &  smoothness\_mean \\
# \midrule
#   842302 &         M &     1.096100 &     -2.071512 &        1.268817 &   0.983510 &         1.567087 \\
#   842517 &         M &     1.828212 &     -0.353322 &        1.684473 &   1.907030 &        -0.826235 \\
# 84300903 &         M &     1.578499 &      0.455786 &        1.565126 &   1.557513 &         0.941382 \\
# 84348301 &         M &    -0.768233 &      0.253509 &       -0.592166 &  -0.763792 &         3.280667 \\
# 84358402 &         M &     1.748758 &     -1.150804 &        1.775011 &   1.824624 &         0.280125 \\
#   843786 &         M &    -0.475956 &     -0.834601 &       -0.386808 &  -0.505206 &         2.235455 \\
# \bottomrule
# \end{tabular}

# %%
#使用NumPy计算Z得分
zscore = (df[num_col] - df[num_col].mean()) / df[num_col].std()
df_zscore = pd.concat([df[['ID','Diagnosis']],zscore],axis=1)

outputpath='C:/Users/shenxuan/Desktop/D1-zscore.csv'
df_zscore.to_csv(outputpath,sep=',',index=False,header=False)

df_zscore
# Out:
#            ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     1.096100     -2.071512        1.268817   0.983510
# 1      842517         M     1.828212     -0.353322        1.684473   1.907030
# 2    84300903         M     1.578499      0.455786        1.565126   1.557513
# 3    84348301         M    -0.768233      0.253509       -0.592166  -0.763792
# 4    84358402         M     1.748758     -1.150804        1.775011   1.824624
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     2.109139      0.720838        2.058974   2.341795
# 565    926682         M     1.703356      2.083301        1.614511   1.722326
# 566    926954         M     0.701667      2.043775        0.672084   0.577445
# 567    927241         M     1.836725      2.334403        1.980781   1.733693
# 568     92751         B    -1.806811      1.220718       -1.812793  -1.346604
#
# ...

# %% [markdown]
# ## min-max归一化

# %%
# 使用NumPy计算最小-最大值归一化
minmax = (df[num_col] - df[num_col].min()) / (df[num_col].max() - df[num_col].min()) 
df_minmax = pd.concat([df[['ID','Diagnosis']],minmax],axis=1)

outputpath='C:/Users/shenxuan/Desktop/D1-minmax.csv'
df_minmax.to_csv(outputpath,sep=',',index=False,header=False)

df_minmax
# Out:
#            ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     0.521037      0.022658        0.545989   0.363733
# 1      842517         M     0.643144      0.272574        0.615783   0.501591
# 2    84300903         M     0.601496      0.390260        0.595743   0.449417
# 3    84348301         M     0.210090      0.360839        0.233501   0.102906
# 4    84358402         M     0.629893      0.156578        0.630986   0.489290
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     0.690000      0.428813        0.678668   0.566490
# 565    926682         M     0.622320      0.626987        0.604036   0.474019
# 566    926954         M     0.455251      0.621238        0.445788   0.303118
# 567    927241         M     0.644564      0.663510        0.665538   0.475716
# 568     92751         B     0.036869      0.501522        0.028540   0.015907
#
# ...

# %%
print(df_minmax.iloc[0:6,0:7].to_latex(index=False))
# Out:
# \begin{tabular}{rlrrrrr}
# \toprule
#       ID & Diagnosis &  radius\_mean &  texture\_mean &  perimeter\_mean &  area\_mean &  smoothness\_mean \\
# \midrule
#   842302 &         M &     0.521037 &      0.022658 &        0.545989 &   0.363733 &         0.593753 \\
#   842517 &         M &     0.643144 &      0.272574 &        0.615783 &   0.501591 &         0.289880 \\
# 84300903 &         M &     0.601496 &      0.390260 &        0.595743 &   0.449417 &         0.514309 \\
# 84348301 &         M &     0.210090 &      0.360839 &        0.233501 &   0.102906 &         0.811321 \\
# 84358402 &         M &     0.629893 &      0.156578 &        0.630986 &   0.489290 &         0.430351 \\
#   843786 &         M &     0.258839 &      0.202570 &        0.267984 &   0.141506 &         0.678613 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## 十进制小数定标法
#
# 该代码首先定义了一个decimal_scaling_normalization函数，
# 然后利用apply方法对DataFrame的每一列应用该函数，
# 实现了Decimal Scaling标准化。
# 最后，将标准化后的DataFrame打印出来，
# 可以看到所有列的数值都在[-1, 1]之间。

# %%
def decimal_scaling_norm(df):
    max_val = np.max(np.abs(df))
    scale = 0
    while max_val >= 1:
        scale += 1
        max_val /= 10
    return df / (10 ** scale)

# 对DataFrame进行Decimal Scaling标准化
decimal_scaled = df_num.apply(decimal_scaling_norm)
df_float = pd.concat([df[['ID','Diagnosis']],decimal_scaled],axis=1)

outputpath='C:/Users/shenxuan/Desktop/D1-float.csv'
df_float.to_csv(outputpath,sep=',',index=False,header=False)

df_float
# Out:
#            ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       0.1799        0.1038         0.12280    0.10010
# 1      842517         M       0.2057        0.1777         0.13290    0.13260
# 2    84300903         M       0.1969        0.2125         0.13000    0.12030
# 3    84348301         M       0.1142        0.2038         0.07758    0.03861
# 4    84358402         M       0.2029        0.1434         0.13510    0.12970
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M       0.2156        0.2239         0.14200    0.14790
# 565    926682         M       0.2013        0.2825         0.13120    0.12610
# 566    926954         M       0.1660        0.2808         0.10830    0.08581
# 567    927241         M       0.2060        0.2933         0.14010    0.12650
# 568     92751         B       0.0776        0.2454         0.04792    0.01810
#
# ...

# %%
print(df_float.iloc[0:6,0:7].to_latex(index=False))
# Out:
# \begin{tabular}{rlrrrrr}
# \toprule
#       ID & Diagnosis &  radius\_mean &  texture\_mean &  perimeter\_mean &  area\_mean &  smoothness\_mean \\
# \midrule
#   842302 &         M &       0.1799 &        0.1038 &         0.12280 &    0.10010 &          0.11840 \\
#   842517 &         M &       0.2057 &        0.1777 &         0.13290 &    0.13260 &          0.08474 \\
# 84300903 &         M &       0.1969 &        0.2125 &         0.13000 &    0.12030 &          0.10960 \\
# 84348301 &         M &       0.1142 &        0.2038 &         0.07758 &    0.03861 &          0.14250 \\
# 84358402 &         M &       0.2029 &        0.1434 &         0.13510 &    0.12970 &          0.10030 \\
#   843786 &         M &       0.1245 &        0.1570 &         0.08257 &    0.04771 &          0.12780 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## logistic逻辑回归标准化
#
# 该代码首先定义了一个logistic_normalization函数，
# 然后利用该函数对给定的数据进行标准化处理。
# 最后，将标准化后的结果打印出来，可以看到所有的数值都在0到1之间。
# 如果需要对一个DataFrame进行logistic标准化，
# 可以将上述代码中的numpy数组替换为DataFrame的列即可。

# %%
def log_norm(df):
    return 1 / (1 + np.exp(-df))

log = log_norm(df_num)
df_log = pd.concat([df[['ID','Diagnosis']],log],axis=1)

outputpath='C:/Users/shenxuan/Desktop/D1-log.csv'
df_log.to_csv(outputpath,sep=',',index=False,header=False)

df_log
# Out:
#            ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M     1.000000      0.999969             1.0        1.0
# 1      842517         M     1.000000      1.000000             1.0        1.0
# 2    84300903         M     1.000000      1.000000             1.0        1.0
# 3    84348301         M     0.999989      1.000000             1.0        1.0
# 4    84358402         M     1.000000      0.999999             1.0        1.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M     1.000000      1.000000             1.0        1.0
# 565    926682         M     1.000000      1.000000             1.0        1.0
# 566    926954         M     1.000000      1.000000             1.0        1.0
# 567    927241         M     1.000000      1.000000             1.0        1.0
# 568     92751         B     0.999574      1.000000             1.0        1.0
#
# ...

# %%
print(df_log.iloc[0:6,0:7].to_latex(index=False))
# Out:
# \begin{tabular}{rlrrrrr}
# \toprule
#       ID & Diagnosis &  radius\_mean &  texture\_mean &  perimeter\_mean &  area\_mean &  smoothness\_mean \\
# \midrule
#   842302 &         M &     1.000000 &      0.999969 &             1.0 &        1.0 &         0.529565 \\
#   842517 &         M &     1.000000 &      1.000000 &             1.0 &        1.0 &         0.521172 \\
# 84300903 &         M &     1.000000 &      1.000000 &             1.0 &        1.0 &         0.527373 \\
# 84348301 &         M &     0.999989 &      1.000000 &             1.0 &        1.0 &         0.535565 \\
# 84358402 &         M &     1.000000 &      0.999999 &             1.0 &        1.0 &         0.525054 \\
#   843786 &         M &     0.999996 &      1.000000 &             1.0 &        1.0 &         0.531907 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## 等距离散化
#
# 确定分为多少个区间需要综合考虑以下几个因素：数据分布情况、数据精度、应用场景。
# 一般来说，选择分为5到10个区间比较常见，但具体的分区数量还需要根据实际情况来确定。
# 另外，需要注意的是，分区数量过多可能会导致过拟合，而分区数量过少可能会影响模型的准确性。
# 因此，在确定分区数量时需要根据具体应用场景进行权衡。

# %%
# 创建一个Series数据
df_radius_mean_series = copy.deepcopy(df['radius_mean'])

# 将数据划分成5个区间
df_radius_mean = df_radius_mean_series.to_frame()
df_radius_mean['bins'] = pd.cut(df_radius_mean['radius_mean'], bins=5)

df_radius_mean_discrete = pd.DataFrame({'radius_mean': df_radius_mean['bins']})
df_radius_mean_discrete
# Out:
#           radius_mean
# 0    (15.433, 19.658]
# 1    (19.658, 23.884]
# 2    (19.658, 23.884]
# 3    (11.207, 15.433]
# 4    (19.658, 23.884]
# ..                ...
# 564  (19.658, 23.884]
# 565  (19.658, 23.884]
# 566  (15.433, 19.658]
# 567  (19.658, 23.884]
# 568    (6.96, 11.207]
#
# [569 rows x 1 columns]

# %%
print(df_radius_mean.iloc[0:6].to_latex(index=False))
# Out:
# \begin{tabular}{rl}
# \toprule
#  radius\_mean &             bins \\
# \midrule
#        17.99 & (15.433, 19.658] \\
#        20.57 & (19.658, 23.884] \\
#        19.69 & (19.658, 23.884] \\
#        11.42 & (11.207, 15.433] \\
#        20.29 & (19.658, 23.884] \\
#        12.45 & (11.207, 15.433] \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## 信息增益离散化

# %% [markdown]
# This code defines three functions: entropy, information_gain, and discretize.
#
# entropy takes a vector y as input and calculates the entropy of y using the formula:
#
# $$H(y) = -\sum_{i=1}^{n} p_i \log_2 p_i$$
#
# where $n$ is the number of unique values in y, $p_i$ is the proportion of samples in y with value $i$.
#
# information_gain takes two vectors x and y, and a scalar split as input. It calculates the information gain of x and y by splitting x at split. The formula for information gain is:
#
# $$IG(x, y, split) = H(y) - [p_{left}H(y_{left}) + p_{right}H(y_{right})]$$
#
# where $H(y)$ is the entropy of y, $p_{left}$ and $p_{right}$ are the proportions of samples that go to the left and right children after the split, and $H(y_{left})$ and $H(y_{right})$ are the entropies of the left and right children.
#
# discretize takes three inputs: vectors x and y, and a scalar num_bins. It discretizes x into num_bins bins by finding the best split point that maximizes information gain (using the information_gain function), and then mapping values in x to either 0 or 1, depending on whether they are less than or equal to the best split point. The function returns the resulting vector.

# %%
def entropy(y):
    # 计算熵
    _, counts = np.unique(y, return_counts=True)
    p = counts / len(y)
    return -np.sum(p * np.log2(p))

def information_gain(x, y, split):
    # 计算分割点为split时的信息增益
    left_mask = x <= split
    right_mask = x > split
    left_entropy = entropy(y[left_mask])
    right_entropy = entropy(y[right_mask])
    p_left = np.sum(left_mask) / len(x)
    p_right = np.sum(right_mask) / len(x)
    return entropy(y) - (p_left * left_entropy + p_right * right_entropy)

def discretize(x, y, num_bins):
    # 将x离散化为num_bins个区间
    x_min, x_max = x.min(), x.max()
    bin_width = (x_max - x_min) / num_bins
    splits = [x_min + i * bin_width for i in range(1, num_bins)]
    gains = [information_gain(x, y, split) for split in splits]
    best_split = splits[np.argmax(gains)]
    # 将x离散化为{<=best_split, >best_split}两个值
    return np.where(x <= best_split, 0, 1)

# %%
tmp = discretize(df['area_mean'], df['Diagnosis'], 5)
df_area_mean_discrete = pd.DataFrame({'area_mean': tmp})
df_area_mean_discrete
# Out:
#      area_mean
# 0            1
# 1            1
# 2            1
# 3            0
# 4            1
# ..         ...
# 564          1
# 565          1
# 566          1
# 567          1
# 568          0
#
# [569 rows x 1 columns]

# %% [markdown]
# ## 卡方离散化
# 这个例子中，qcut函数将数据划分为4个等频区间，然后使用卡方检验来计算区间边界。retbins=True表示返回每个区间的边界，duplicates='drop'表示去除重复值，labels=False表示返回每个区间的索引而不是标签。函数返回一个Categorical对象和一个列表，列表中的元素表示每个区间的边界。

# %%
# 创建一个Series数据
df_texture_mean_series = copy.deepcopy(df['texture_mean'])

# 将数据划分成4个区间，使用卡方检验计算区间边界
df_texture_mean, bins = pd.qcut(df_texture_mean_series, q=4, retbins=True, duplicates='drop', labels=False)

# 打印结果
df_texture_mean_discrete = df_texture_mean.to_frame()
df_texture_mean_discrete

# result = result.rename(columns={'texture_mean': 'texture_mean_bins'}) 可以修改列名
# Out:
#      texture_mean
# 0               0
# 1               1
# 2               2
# 3               2
# 4               0
# ..            ...
# 564             3
# 565             3
# 566             3
# 567             3
# 568             3
#
# [569 rows x 1 columns]

# %% [markdown]
# ## CAIM离散化

# %%
def CAIM(df, col, num_bins):
    # 将数据按照指定列排序
    data = df.sort_values(by=col)[[col, 'Diagnosis']]
    data.reset_index(inplace=True, drop=True)
    n = len(data)

    # 生成候选划分点
    cut_points = [data[col].iloc[i] for i in range(num_bins - 1)]
    max_cramer_v = 0
    final_cut_point = None

    # 计算每个候选划分点的Cramer's V值
    for cut_point in cut_points:
        left = data[data[col] <= cut_point]
        right = data[data[col] > cut_point]
        n_left = len(left)
        n_right = len(right)

        # 计算左侧和右侧的类别属性分布
        left_dist = left['Diagnosis'].value_counts().sort_index().tolist()
        right_dist = right['Diagnosis'].value_counts().sort_index().tolist()

        # 计算左侧和右侧的总类别属性数量
        n_total_left = sum(left_dist)
        n_total_right = sum(right_dist)

        # 计算左侧和右侧的类别属性概率分布
        left_prob = [x / n_total_left for x in left_dist]
        right_prob = [x / n_total_right for x in right_dist]

        # 计算Cramer's V值
        p_total = (n_total_left + n_total_right) / n
        p_left = n_total_left / n
        p_right = n_total_right / n
        v = p_total * (
            sum([x**2 for x in left_prob]) / p_left +
            sum([x**2 for x in right_prob]) / p_right -
            (sum([x**2 for x in left_prob + right_prob]) / p_total)
        )

        # 更新最大Cramer's V值和最终的划分点
        if v > max_cramer_v:
            max_cramer_v = v
            final_cut_point = cut_point

    # 返回最终的划分点
    return final_cut_point

# %% [markdown]
# 上述代码中，df是一个包含原始数据的pandas DataFrame，col是需要离散化的列名，num_bins是希望将该列分成的离散型取值数量。CAIM函数会返回最终的划分点。
#
# 需要注意的是，这里使用了Cramer's V值作为衡量类别属性相互依赖程度的指标，而且代码中对Cramer's V值的计算方式也只是一种可能的方式。在实际应用中，需要根据具体情况选择合适的指标和计算方式。

# %% [markdown]
# 现在，我们使用CAIM函数将X列离散化为5个取值，然后再统计每个取值下target变量的分布情况。

# %% [markdown]
# 上述代码中，我们将X列分为两个离散值，标签分别为0和1，然后使用groupby方法计算每个离散值下target变量的分布情况。运行结果如下：可以看到，离散化后，连续型变量X被划分为了两个离散值，取值为0和1。同时，我们还计算了每个离散值下target变量的分布情况，可以用于后续的建模分析。

# %%
cut_point = CAIM(df, 'perimeter_mean', 5)
df['perimeter_mean_discrete'] = pd.cut(df['perimeter_mean'], [-np.inf, cut_point, np.inf], labels=[0, 1])
df.groupby('perimeter_mean_discrete')['Diagnosis'].value_counts(normalize=True)
# Out:
# perimeter_mean_discrete  Diagnosis
# 0                        B            1.000000
# 1                        B            0.626761
#                          M            0.373239
# Name: Diagnosis, dtype: float64

# %%
df_perimeter_mean_discrete = pd.DataFrame({'perimeter_mean': df['perimeter_mean_discrete']})

# %%
df_discrete = pd.concat([df[['ID','Diagnosis']],df_radius_mean_discrete,df_texture_mean_discrete,df_perimeter_mean_discrete,df_area_mean_discrete,df.iloc[0:,6:]],axis=1)

outputpath='C:/Users/shenxuan/Desktop/D1-discrete.csv'
df_discrete.to_csv(outputpath,sep=',',index=False,header=False)

# %% [markdown]
# ## 添加噪声，形成离群点

# %%
df_d2 = copy.deepcopy(df[['radius_worst','texture_wost']])
df_d2
# Out:
#      radius_worst  texture_wost
# 0          25.380         17.33
# 1          24.990         23.41
# 2          23.570         25.53
# 3          14.910         26.50
# 4          22.540         16.67
# ..            ...           ...
# 564        25.450         26.40
# 565        23.690         38.25
# 566        18.980         34.12
# 567        25.740         39.42
# 568         9.456         30.37
#
# [569 rows x 2 columns]

# %%
print(df_d2.iloc[0:10,].to_latex(index=False))
# Out:
# \begin{tabular}{rr}
# \toprule
#  radius\_worst &  texture\_wost \\
# \midrule
#         25.38 &         17.33 \\
#         24.99 &         23.41 \\
#         23.57 &         25.53 \\
#         14.91 &         26.50 \\
#         22.54 &         16.67 \\
#         15.47 &         23.75 \\
#         22.88 &         27.66 \\
#         17.06 &         28.14 \\
#         15.49 &         30.73 \\
#         15.09 &         40.68 \\
# \bottomrule
# \end{tabular}

# %%
noise = np.random.uniform(low=-40, high=40, size=(569, 2))
df_noisy = df_d2 + noise

outputpath='C:/Users/shenxuan/Desktop/D2.csv'
df_noisy.to_csv(outputpath,sep=',',index=False,header=False)

# %% [markdown]
# 局部离群因子（LOF）算法是一种用于检测数据集中异常值的算法，它基于密度的概念，可以有效地识别那些在周围数据密度相对较低的点。以下是LOF算法的步骤：
#
# 为数据集中的每个数据点计算它们与所有其他数据点之间的距离。
#
# 对于每个数据点，确定它的k个最近邻数据点，这些最近邻数据点被称为该数据点的k-邻域。k的值可以通过交叉验证或经验法则进行选择。
#
# 计算每个数据点的局部可达密度（LRD），它表示数据点周围区域的密度，是数据点到其k-邻域中所有点距离的平均值的倒数。一个点的密度越大，其LRD越小。
#
# 对于每个数据点，计算其k-邻域中每个邻居点的局部可达密度，然后将它们的平均值除以该数据点的局部可达密度，得到它的局部离群因子（LOF）值。LOF值表示数据点与其邻居的密度比较，如果LOF值接近1，则该点与其邻居的密度相似，如果LOF值大于1，则该点的密度相对较小，被认为是一个离群点。
#
# 通过选择一个LOF值阈值，将数据集中的所有数据点分为离群点和非离群点。这个阈值可以根据经验或者交叉验证来选择。
#
# LOF算法可以帮助我们找到数据集中相对于其他点更为孤立的点，它不需要事先对数据进行假设或者参数化，因此适用于各种类型的数据集。

# %%
from sklearn.neighbors import NearestNeighbors

def LOF(X, k):
    """
    计算数据集X的局部离群因子(LOF)值。

    参数：
    X: 二维数组，表示数据集。
    k: int，表示k-邻域的大小。

    返回：
    lof_scores: 一维数组，表示每个数据点的LOF值。
    """

    # 计算每个数据点到其他数据点的距离
    nbrs = NearestNeighbors(n_neighbors=k+1).fit(X)
    distances, indices = nbrs.kneighbors(X)

    # 计算每个数据点的k-邻域可达距离
    reachability_dists = np.zeros(X.shape[0])
    for i in range(X.shape[0]):
        k_dist = distances[i, -1] # k-邻域距离
        reachability_dists[i] = max(k_dist, np.sum(distances[indices[i], -1]) / k)

    # 计算每个数据点的局部可达密度(LRD)
    lrd = 1.0 / (np.mean(reachability_dists[indices], axis=1) + 1e-10)

    # 计算每个数据点的LOF值
    lof_scores = np.zeros(X.shape[0])
    for i in range(X.shape[0]):
        lof_scores[i] = np.mean(lrd[indices[i]]) / lrd[i]

    return lof_scores

# %% [markdown]
# 选择适当的k值对于LOF算法的性能和准确性至关重要。k值的选择可以根据数据集的特点和应用领域的需求来进行。
#
# 通常，可以通过试验不同的k值并比较结果来选择最佳的k值。一般来说，k值越大，LOF算法越具有全局性，可以更好地发现全局离群值。但是，如果k值过大，LOF算法将变得过于保守，无法发现一些局部离群值。
#
# 对于大多数数据集，一个通用的经验法则是将k值设置为5到10之间的整数。当然，在实际应用中，还需要根据数据集的特点和需求进行适当的调整。另外，可以使用其他自动选择k值的方法，如基于密度的选择或基于距离的选择，这些方法可以根据数据集的性质自动选择k值。

# %%
# 使用LOF算法计算LOF值
lof_scores = LOF(df_noisy.values, k=5)

# 标识离群点
thresholds = [1, 1.1, 1.5]
fig, axs = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,6))
for i, threshold in enumerate(thresholds):
    lof_scores = LOF(df_noisy.values, k=5)
    outliers = lof_scores > threshold
    
    # 绘制散点图
    plt.subplot(1, 3, i+1)
    plt.scatter(df_noisy.loc[~outliers, 'radius_worst'], df_noisy.loc[~outliers, 'texture_wost'], color='blue', label='normal')
    plt.scatter(df_noisy.loc[outliers, 'radius_worst'], df_noisy.loc[outliers, 'texture_wost'], color='red', label='outlier')
    plt.legend()
    plt.title(f"Threshold={threshold}")
    
plt.tight_layout()
fig.savefig('scatterplot.png', dpi=300)
plt.show()
